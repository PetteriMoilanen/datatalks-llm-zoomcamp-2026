# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def llm(prompt):
    # Use standard OpenAI chat completion syntax
    response = openai_client.chat.completions.create(
        model="gemini-2.5-flash",
        messages=[{"role": "user", "content": prompt}]  # OpenAI requires a list of message objects
    )
    
    # Extract the text the OpenAI way
    return response.choices[0].message.content

# %%
llm("Hey, what's up?")
# Out:
# "Hey! Not much, just doing my AI thing. What's up with you?"
